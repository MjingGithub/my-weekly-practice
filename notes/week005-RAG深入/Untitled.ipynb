# %% [markdown]
# 发现一个基于RAG的创业产品。公司的架构是采用JAVA+python的方式，项目架构图如下，你们使用的技术栈可以参考。
#
# 参考：[创业：大模型RAG系统三个月的开发心得和思考](https://www.xiaominfo.com/2024/04/01/torchv-summary-01/)
#
# ![image.png](attachment:b7c4ee81-527e-427e-9ffe-02d1041f36a2.png)
